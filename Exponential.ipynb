# %% [markdown]
# # Details
#
# This notebook is a notebook to compare the simulated values of the exponential function $ e^x $ and the exponential series expansion.
# <br>
# <br>
# Link: <a href="//towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd}">LaTeX</a>

# %% [markdown]
# # Libraries

# %%
# from numpy import random
import matplotlib.pyplot as plt 
import math
# import seaborn as sns

# %% [markdown]
# # exponential function

# %%
x = [math.exp(n) for n in range(100)]
print(x)
# Out:
# [1.0, 2.718281828459045, 7.38905609893065, 20.085536923187668, 54.598150033144236, 148.4131591025766, 403.4287934927351, 1096.6331584284585, 2980.9579870417283, 8103.083927575384, 22026.465794806718, 59874.14171519782, 162754.79141900392, 442413.3920089205, 1202604.2841647768, 3269017.3724721107, 8886110.520507872, 24154952.7535753, 65659969.13733051, 178482300.96318725, 485165195.4097903, 1318815734.4832146, 3584912846.131592, 9744803446.248903, 26489122129.84347, 72004899337.38588, 195729609428.83878, 532048240601.7986, 1446257064291.475, 3931334297144.042, 10686474581524.463, 29048849665247.426, 78962960182680.69, 214643579785916.06, 583461742527454.9, 1586013452313430.8, 4311231547115195.0, 1.1719142372802612e+16, 3.1855931757113756e+16, 8.659340042399374e+16, 2.3538526683702e+17, 6.398434935300549e+17, 1.739274941520501e+18, 4.727839468229346e+18, 1.2851600114359308e+19, 3.4934271057485095e+19, 9.496119420602448e+19, 2.5813128861900675e+20, 7.016735912097631e+20, 1.9073465724950
# ...

# %% [markdown]
# # Exponential Series Expansion

# %%
def exp_series(z, n):
    y = sum([z**n/math.factorial(i) for i in range(n)])
    print(y)
    return y

# %%
y = [exp_series(i, 5) for i in range(100)]
print(y)
# Out:
# 0.0
# 2.708333333333333
# 86.66666666666666
# 658.125
# 2773.333333333333
# 8463.541666666668
# 21060.0
# 45518.95833333333
# 88746.66666666666
# 159924.375
# 270833.3333333334
# 436179.7916666666
# 673920.0
# 1005585.2083333333
# 1456606.6666666665
# 2056640.625
# 2839893.333333333
# 3845446.041666667
# 5117580.0
# 6706101.458333334
# 8666666.666666668
# 11061106.875
# 13957753.333333332
# 17431762.291666664
# 21565440.0
# 26448567.708333336
# 32178726.666666664
# 38861623.125
# 46611413.33333333
# 55551028.54166667
# 65812500.0
# 77537283.95833334
# 90876586.66666666
# 105991689.375
# 123054273.33333334
# 142246744.7916667
# 163762560.0
# 187806550.2083333
# 214595246.6666667
# 244357205.625
# 277333333.3333334
# 313777211.0416666
# 353955420.0
# 398147866.4583334
# 446648106.6666666
# 499763671.875
# 557816393.3333333
# 621142727.2916667
# 690094080.0
# 765037132.7083333
# 846354166.6666667
# 934443388.125
# 1029719253.3333333
# 1132612793.5416665
# 1243571940.0
# ...
